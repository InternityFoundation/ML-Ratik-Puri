# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('BlackFriday.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.describe()
# Out:
#             User_ID    Occupation  Marital_Status  Product_Category_1  \
# count  5.375770e+05  537577.00000   537577.000000       537577.000000
# mean   1.002992e+06       8.08271        0.408797            5.295546
# std    1.714393e+03       6.52412        0.491612            3.750701
# min    1.000001e+06       0.00000        0.000000            1.000000
# 25%    1.001495e+06       2.00000        0.000000            1.000000
# 50%    1.003031e+06       7.00000        0.000000            5.000000
# 75%    1.004417e+06      14.00000        1.000000            8.000000
# max    1.006040e+06      20.00000        1.000000           18.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       370591.000000       164278.000000  537577.000000
# mean             9.842144           12.669840    9333.859853
# std              5.087259            4.124341    4981.022133
# min              2.000000            3.000000     185.000000
# ...

# %%
del df['User_ID']

# %%
del df['Product_ID']

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
def getnum(g):
    if(g=="M"):
        return 1
    else:
        return 0

df['Gender']=df['Gender'].apply(getnum)

# %%
len(df)
# Out:
# 537577

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
import seaborn as sns

# %%
set(df['Gender'])
# Out:
# {0, 1}

# %%
# set(df['Age'])

# %%
# set(df['Occupation'])

# %%
# set(df['City_Category'])

# %%
def getnum(c):
    if(c=="A"):
        return 1
    elif(c=="B"):
        return 2
    else:
        return 3

df['City_Category']=df['City_Category'].apply(getnum)

# %%
# set(df['Stay_In_Current_City_Years'])

# %%
set(df['Marital_Status'])
# Out:
# {0, 1}

# %%
df.head()
# Out:
#    Gender   Age  Occupation  City_Category Stay_In_Current_City_Years  \
# 0       0  0-17          10              1                          2
# 1       0  0-17          10              1                          2
# 2       0  0-17          10              1                          2
# 3       0  0-17          10              1                          2
# 4       1   55+          16              3                         4+
#
#    Marital_Status  Product_Category_1  Purchase
# 0               0                   3      8370
# 1               0                   1     15200
# 2               0                  12      1422
# 3               0                  12      1057
# 4               0                   8      7969

# %%
def getnum(c):
    if(c=='4+'):
        return 5

df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].apply(getnum)

# %%
def getnum(s):
    if(s=='55+'):
        return 55
    else:
        l=s.split('-')
        return (int(l[0])+int(l[1]))/2
df['Age']=df['Age'].apply(getnum)

# %%
df.head()
# Out:
#    Gender   Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0       0   8.5          10              1                         NaN
# 1       0   8.5          10              1                         NaN
# 2       0   8.5          10              1                         NaN
# 3       0   8.5          10              1                         NaN
# 4       1  55.0          16              3                         5.0
#
#    Marital_Status  Product_Category_1  Purchase
# 0               0                   3      8370
# 1               0                   1     15200
# 2               0                  12      1422
# 3               0                  12      1057
# 4               0                   8      7969

# %%
# set(df['Stay_In_Current_City_Years'])

# %%
df.isnull().sum()
# Out:
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years    454688
# Marital_Status                     0
# Product_Category_1                 0
# Purchase                           0
# dtype: int64

# %%
len(df)
# Out:
# 537577

# %%
del df['Stay_In_Current_City_Years']

# %%
df.head()
# Out:
#    Gender   Age  Occupation  City_Category  Marital_Status  \
# 0       0   8.5          10              1               0
# 1       0   8.5          10              1               0
# 2       0   8.5          10              1               0
# 3       0   8.5          10              1               0
# 4       1  55.0          16              3               0
#
#    Product_Category_1  Purchase
# 0                   3      8370
# 1                   1     15200
# 2                  12      1422
# 3                  12      1057
# 4                   8      7969

# %%
x=df.iloc[:,:6].values

# %%
x[0]
# Out:
# array([ 0. ,  8.5, 10. ,  1. ,  0. ,  3. ])

# %%
y=df['Purchase'].values

# %%
y
# Out:
# array([ 8370, 15200,  1422, ...,  8043,  7172,  6875], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
clf=LinearRegression()

# %%
clf.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
 clf.score(x_test,y_test)
# Out:
# 0.10562395436581196

# %%
from sklearn.linear_model import ElasticNet

# %%
clf=ElasticNet(alpha=0.000001)

# %%
clf.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=1e-06, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
 clf.score(x_test,y_test)
# Out:
# 0.10561370785234235

# %%
from sklearn.linear_model import Ridge

# %%
clf=Ridge(alpha=0.00001)

# %%
clf.fit(x_train,y_train)
# Out:
# Ridge(alpha=1e-05, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
clf.score(x_test,y_test)
# Out:
# 0.10561370772851597

# %%
t=pd.read_csv('test.csv')

# %%
t
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# 5       1000013  P00350442      M  46-50           1             C
# 6       1000013  P00155442      M  46-50           1             C
# 7       1000013   P0094542      M  46-50           1             C
# 8       1000015  P00161842      M  26-35           7             A
# 9       1000022  P00067942      M  18-25          15             A
# 10      1000026  P00046742      M  26-35           7             B
# 11      1000026  P00040042      M  26-35           7             B
# 12      1000026  P00196542      M  26-35           7             B
# ...

# %%
def getnum(g):
    if(g=="M"):
        return 1
    else:
        return 0

t['Gender']=t['Gender'].apply(getnum)

# %%
def getnum(c):
    if(c=="A"):
        return 1
    elif(c=="B"):
        return 2
    else:
        return 3

t['City_Category']=t['City_Category'].apply(getnum)

# %%
def getnum(c):
    if(c=='4+'):
        return 5

t['Stay_In_Current_City_Years']=t['Stay_In_Current_City_Years'].apply(getnum)

# %%
def getnum(s):
    if(s=='55+'):
        return 55
    else:
        l=s.split('-')
        return (int(l[0])+int(l[1]))/2
t['Age']=t['Age'].apply(getnum)

# %%
t.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation  City_Category  \
# 0  1000004  P00128942       1  48.0           7              2
# 1  1000009  P00113442       1  30.5          17              3
# 2  1000010  P00288442       0  40.5           1              2
# 3  1000010  P00145342       0  40.5           1              2
# 4  1000011  P00053842       0  30.5           1              3
#
#    Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                         NaN               1                   1
# 1                         NaN               0                   3
# 2                         5.0               1                   5
# 3                         5.0               1                   4
# 4                         NaN               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# ...

# %%
t.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years    197654
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2             72344
# Product_Category_3            162562
# dtype: int64

# %%
del t['Stay_In_Current_City_Years']

# %%
del t['Product_Category_2']
del t['Product_Category_3']

# %%
t.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation  City_Category  \
# 0  1000004  P00128942       1  48.0           7              2
# 1  1000009  P00113442       1  30.5          17              3
# 2  1000010  P00288442       0  40.5           1              2
# 3  1000010  P00145342       0  40.5           1              2
# 4  1000011  P00053842       0  30.5           1              3
#
#    Marital_Status  Product_Category_1
# 0               1                   1
# 1               0                   3
# 2               1                   5
# 3               1                   4
# 4               0                   4

# %%
xt=t.iloc[:,2:].values

# %%
xt[0]
# Out:
# array([ 1., 48.,  7.,  2.,  1.,  1.])

# %%
xt.shape,x_train.shape
# Out:
# ((233599, 6), (403182, 6))

# %%
ypred=clf.predict(xt)

# %%
uid=t['User_ID'].values

# %%
pid=t['Product_ID'].values

# %%
uid.shape,pid.shape,len(ypred)
# Out:
# ((233599,), (233599,), 233599)

# %%
s=np.c_[uid,pid,ypred]

# %%
s[0]
# Out:
# array([1000004, 'P00128942', 11391.190185440639], dtype=object)

# %%
np.savetxt('black.csv',s,header="User_ID,Product_ID,Purchase",delimiter=',',fmt="%s,%s,%s")
